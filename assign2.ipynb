# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("housing_prices.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
df.shape
# Out:
# (1459, 80)

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
# Length: 80, dtype: int64

# %%
num_cols = df.select_dtypes(include=['Int64','Float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         1
# SaleCondition    0
# Length: 80, dtype: int64

# %%
cat_cols = df.select_dtypes(include=["object"]).columns

for col in cat_cols:
    mode_value = df[col].mode()  # Get the mode

    if not mode_value.empty:  # Check if mode exists
        df[col] = df[col].fillna(mode_value[0])  
    else:
        df[col] = df[col].fillna("Unknown")  # Use 'Unknown' as fallback

# %%
df.drop(columns=['Id'], inplace=True)  # Drop 'Id' if it's unnecessary
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.drop(columns=['Id'], inplace=True)  # Drop 'Id' if it's unnecessary
#
# File c:\Users\ADMIN\Desktop\Internship\venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.to_csv("cleaned_housing_prices.csv", index=False)
print("Cleaned dataset saved successfully! ✅")
# Out:
# Cleaned dataset saved successfully! ✅

# %%
# Select only numeric columns
num_cols = df.select_dtypes(include=["int64", "float64"]).columns.tolist()

# Exclude 'Id' or any non-relevant column if necessary
num_cols = [col for col in num_cols if col != "Id"]

# Apply MinMaxScaler only to valid numerical columns
scaler = MinMaxScaler()
df[num_cols] = scaler.fit_transform(df[num_cols])
